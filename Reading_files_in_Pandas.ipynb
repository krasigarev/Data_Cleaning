# %% [markdown]
# # Reading File with Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Read in CSV File

# %% [markdown]
# ## Read in TXT File

# %% [markdown]
# ## Read in JSON File

# %% [markdown]
# ## Read in XLSX File
